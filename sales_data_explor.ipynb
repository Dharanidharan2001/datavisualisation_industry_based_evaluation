# %% [markdown]
#                                   SALES DATA EXPLORATION | | |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)

# %%
sales_data=pd.read_csv('Car_sales.csv')
sales_data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
sales_data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sales_subset=sales_data[['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
       'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Width', 'Length', 'Fuel_capacity',
       'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor']]
       
sales_subset
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Width  Length  \
# 0      Passenger               21.50          1.8       140.0   67.3   172.4
# ...

# %%
sales_subset.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Width                   1
# Length                  1
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
sales_subset[sales_subset['__year_resale_value'].isna()]
# Out:
#     Manufacturer      Model  Sales_in_thousands  __year_resale_value  \
# 7            BMW       323i              19.747                  NaN
# 18      Cadillac   Escalade              14.785                  NaN
# 27     Chevrolet     Impala             107.995                  NaN
# 34      Chrysler       300M              30.696                  NaN
# 44         Dodge    Durango             101.323                  NaN
# 50          Ford      Focus             175.670                  NaN
# 66        Jaguar     S-Type              15.467                  NaN
# 72         Lexus      GS400               3.334                  NaN
# 74         Lexus      LX470               9.126                  NaN
# 75         Lexus      RX300              51.238                  NaN
# 78       Lincoln  Navigator              22.925                  NaN
# 96    Mercedes-B        SLK               7.998                  NaN
# 97    Mercedes-B     SLK230               1.526                  NaN
# ...

# %%
sales_subset.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower       Width      Length  Fuel_capacity  \
# count   156.000000  156.000000  156.000000  156.000000     156.000000
# mean      3.060897  185.948718   71.150000  187.343590      17.951923
# std       1.044653   56.700321    3.451872   13.431754       3.887921
# min       1.000000   55.000000   62.600000  149.400000      10.300000
# ...

# %%
sales_data.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
sales_subset.hist(figsize=(20,15),grid=False, bins=20, rwidth=0.9,
                   color='#607c8e')
# Out:
# array([[<AxesSubplot:title={'center':'Sales_in_thousands'}>,
#         <AxesSubplot:title={'center':'__year_resale_value'}>,
#         <AxesSubplot:title={'center':'Price_in_thousands'}>],
#        [<AxesSubplot:title={'center':'Engine_size'}>,
#         <AxesSubplot:title={'center':'Horsepower'}>,
#         <AxesSubplot:title={'center':'Width'}>],
#        [<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'Fuel_capacity'}>,
#         <AxesSubplot:title={'center':'Fuel_efficiency'}>],
#        [<AxesSubplot:title={'center':'Power_perf_factor'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
cars_with_good_hp=sales_subset[sales_subset['Horsepower']>180]
cars_with_good_hp
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 1          Acura            TL              39.384               19.875
# 2          Acura            CL              14.114               18.225
# 3          Acura            RL               8.588               29.725
# 5           Audi            A6              18.780               23.555
# 6           Audi            A8               1.380               39.000
# ..           ...           ...                 ...                  ...
# 138       Toyota        Avalon              63.849               18.140
# 141       Toyota        Sienna              65.119                  NaN
# 144       Toyota  Land Cruiser               9.835               34.080
# 155        Volvo           C70               3.493                  NaN
# 156        Volvo           S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Width  Length  \
# ...

# %%
cars_with_good_hp[['Horsepower','Sales_in_thousands']].plot(kind='scatter',x='Horsepower',y='Sales_in_thousands',figsize=(20,7))
# Out:
# <AxesSubplot:xlabel='Horsepower', ylabel='Sales_in_thousands'>

# %%
manuniq=sales_subset.Manufacturer.unique()

#uniqmod=sales_subset.Model.unique()
manuniq
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
sales_subset['Manufacturer'].value_counts()
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %%
sales_subset['Model'].value_counts()
# Out:
# Neon          2
# Integra       1
# Cutlass       1
# Sentra        1
# Altima        1
#              ..
# Windstar      1
# Expedition    1
# Ranger        1
# F-Series      1
# S80           1
# Name: Model, Length: 156, dtype: int64

# %%
sales_data.keys()
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
salesdf=sales_data[['Sales_in_thousands', '__year_resale_value',
       'Price_in_thousands', 'Engine_size', 'Horsepower', 'Width', 'Length', 'Fuel_capacity',
       'Fuel_efficiency', 'Power_perf_factor']]

# %%
df=pd.DataFrame(salesdf)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.fillna(0, inplace=True)
df
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0                16.919               16.360               21.50          1.8
# 1                39.384               19.875               28.40          3.2
# 2                14.114               18.225                0.00          3.2
# 3                 8.588               29.725               42.00          3.5
# 4                20.397               22.255               23.99          1.8
# ..                  ...                  ...                 ...          ...
# 152               3.545                0.000               24.40          1.9
# 153              15.245                0.000               27.50          2.4
# 154              17.531                0.000               28.80          2.4
# 155               3.493                0.000               45.50          2.3
# 156              18.969                0.000               36.00          2.9
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler=StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(df)
scaled_data
# Out:
# array([[-0.53204229,  0.19341907, -0.38109112, ..., -1.12600487,
#          0.86334364, -0.67464291],
#        [-0.20076081,  0.47306822,  0.09339649, ..., -0.15480441,
#          0.30169329,  0.58080442],
#        [-0.5734064 ,  0.34179622, -1.859567  , ..., -0.15480441,
#          0.48891007, -2.88577224],
#        ...,
#        [-0.5230174 , -1.10816274,  0.12090302, ...,  0.01515568,
#          0.30169329, -0.18613831],
#        [-0.73002962, -1.10816274,  1.26930056, ...,  0.16083575,
#         -0.07274028,  0.96978385],
#        [-0.50181184, -1.10816274,  0.61602052, ...,  0.79211605,
#          0.11447651,  0.36700974]])

# %%
pca=PCA(n_components=2)
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (157, 10)

# %%
x_pca.shape
# Out:
# (157, 2)

# %%
scaled_data
# Out:
# array([[-0.53204229,  0.19341907, -0.38109112, ..., -1.12600487,
#          0.86334364, -0.67464291],
#        [-0.20076081,  0.47306822,  0.09339649, ..., -0.15480441,
#          0.30169329,  0.58080442],
#        [-0.5734064 ,  0.34179622, -1.859567  , ..., -0.15480441,
#          0.48891007, -2.88577224],
#        ...,
#        [-0.5230174 , -1.10816274,  0.12090302, ...,  0.01515568,
#          0.30169329, -0.18613831],
#        [-0.73002962, -1.10816274,  1.26930056, ...,  0.16083575,
#         -0.07274028,  0.96978385],
#        [-0.50181184, -1.10816274,  0.61602052, ...,  0.79211605,
#          0.11447651,  0.36700974]])

# %%
x_pca
# Out:
# array([[ 2.03731497e+00,  6.89714753e-01],
#        [-6.89856920e-01,  3.15052992e-01],
#        [ 1.49630964e+00, -8.52905579e-01],
#        [-1.50010865e+00,  8.89714587e-01],
#        [ 1.32096093e+00,  5.77318265e-01],
#        [-9.31438072e-01,  1.93982537e-01],
#        [-4.45715987e+00,  1.60207595e+00],
#        [ 1.03860095e+00,  1.56574758e-01],
#        [-1.31083707e-01,  1.34205140e+00],
#        [-8.06162637e-01,  1.01284591e+00],
#        [ 1.86860645e-01, -8.19473600e-01],
#        [-1.16469085e+00, -8.43381251e-02],
#        [-1.31815329e+00, -3.52159956e-01],
#        [-7.74350253e-01, -6.75382069e-01],
#        [-2.84629450e+00,  8.11608895e-02],
#        [-3.03393716e+00,  7.19405864e-01],
#        [-2.92616712e+00,  5.65158635e-01],
#        [-5.75820037e-01,  3.77132249e-01],
#        [-4.10970068e+00, -7.41203948e-01],
#        [ 2.39109095e+00, -8.77635625e-01],
#        [ 8.76807025e-01, -7.69854642e-01],
#        [ 2.68923706e-01, -6.61780312e-01],
# ...

# %%
colors = np.random.rand(10)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=salesdf['Sales_in_thousands'],cmap='plasma')
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
# Out:
# Text(0, 0.5, 'Second principle component')

# %%
pca.components_
# Out:
# array([[ 0.04639896, -0.2085689 , -0.36233615, -0.40409186, -0.41651565,
#         -0.29129753, -0.27350243, -0.33752506,  0.20576827, -0.4127488 ],
#        [-0.39112978,  0.35578642,  0.30746695, -0.03370575,  0.14014317,
#         -0.46563324, -0.51357698, -0.24755702, -0.1719456 ,  0.18356473]])

# %%
df_comp = pd.DataFrame(pca.components_,columns=salesdf.keys())

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(df_comp,cmap='plasma',)
# Out:
# <AxesSubplot:>
